# %%
import pandas as pd
from ydata_profiling import ProfileReport
from pathlib import Path

# %%
DATA_PATH = Path("../data/raw/olist_orders_dataset.csv")

df_orders = pd.read_csv(DATA_PATH)

# %%
df_orders.head()

# %%
df_orders.shape

# %%
df_orders.info()

# %%
profile = ProfileReport(
    df_orders,
    title="Olist Orders Dataset - Data Profiling",
    explorative=True
)

# %%
profile

# %%
REPORT_PATH = Path("../reports/olist_orders_profile.html")

profile.to_file(REPORT_PATH)
